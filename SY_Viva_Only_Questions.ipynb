# %% [markdown]
# # SY Viva
#
# - Name
# - Division
# - Roll Number
#
# ## Instructions
# 1. Answer the two questions below by 4:45 pm
# 2. Upload your work to Github by 4:50 pm. No submissions uploaded after 4:40 pm will be reviewed.
# 3. Invite the following collaborators to the Github Repo: jjadvani01, zoshuateaching, sheamehta, DishaVasa
# 4. Submit a link to your Github repository on Google Classroom.
# 5. Once completed, raise your hand on Zoom
# 6. You will be sent to a breakout room for 5 minutes to explain your solution. Your TA will ask you to explain the code you have written. All you need to do is to explain what each line of code does. During the meeting, the TA will not tell you if you are correct or wrong. They will only take notes on your answers.
# 7
# . Once your Viva is completed, you may feel free to drop off the call.

# %% [markdown]
# # Part 1: Do Not Touch

# %%
# DO NOT DELETE: Import the Pandas, Seaborn, and Matplotlib Packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# DO NOT DELETE: Print all rows of all dataframes
pd.set_option('display.max_rows', None)
pd.options.display.float_format = "{:,.2f}".format

# %% [markdown]
# # Part 2: Importing the Data

# %%
# Import the "Australian_Grocery_Store_Data_2017.csv" and save it as a dataframe called trans_df
trans_df = pd.read_csv("Australian_Grocery_Store_Data_2017.csv")

# Print the first 5 rows of trans_2017_df. You should see dates from the year 2017 present
trans_df.head(5)
# Out:
#                              receipt_id                   date  item_code  \
# 0  4c4c9a80-b861-445e-9abc-6e70e84fd0d3  2/17/2017 12:17:17 AM       2003
# 1  65d59c3b-b474-482f-8779-3249d6fee305   2/2/2017 10:14:16 PM       2003
# 2  4443f4db-a5ba-4693-a6e1-70840ce6076e   2/21/2017 2:11:10 AM       2003
# 3  3399ecfd-f809-4653-9310-d41015e09f8a   1/10/2017 3:11:14 AM       2003
# 4  085663fa-1fde-4ffc-adfc-527599065a87    2/3/2017 2:16:10 AM       2003
#
#           item_name  quantity payment_type  unit_buying_price  \
# 0  Apples Pink Lady      0.14         cash               0.00
# 1  Apples Pink Lady      0.15         cash               0.00
# 2  Apples Pink Lady      0.15         cash               0.00
# 3  Apples Pink Lady      0.15         cash               0.00
# 4  Apples Pink Lady      0.16         cash               0.00
#
#    unit_selling_price  unit_price_margin
# 0                2.99               2.99
# 1                2.99               2.99
# 2                2.99               2.99
# 3                2.99               2.99
# 4                2.99               2.99

# %%
# Create and print a variable called "total_rows" that tells us How many rows in total are present in trans_df
total_rows = len(trans_df)

# %% [markdown]
# # Part 3: Adding Arithmetic Columns

# %%
# Add a column called "total_buying_price" (Formula: unit_buying_price * quantity)
trans_df["total_buying_price"] = trans_df["unit_buying_price"] * trans_df["quantity"]
# Add a column called "total_selling price" (Formula: unit_selling_price * quantity)
trans_df["total_selling_price"] = trans_df["unit_selling_price"] * trans_df["quantity"]
# Add a column called "total_margin" (Formula: unit_price_margin * quantity)
trans_df["total_margin"] = trans_df["unit_price_margin"] * trans_df["quantity"]
# Print the first 5 rows of trans_df to show that these columns have been added
trans_df.head(50)
# Out:
#                               receipt_id                   date  item_code  \
# 36                2.99               2.99                0.00
# 37                2.99               2.99                0.00
# 38                2.99               2.99                0.00
# 39                2.99               2.99                0.00
# 40                2.99               2.99                0.00
# 41                2.99               2.99                0.00
# 42                2.99               2.99                0.00
# 43                2.99               2.99                0.00
# 44                2.99               2.99                0.00
# 45                2.99               2.99                0.00
# 46                2.99               2.99                0.00
# 47                2.99               2.99                0.00
# 48                2.99               2.99                0.00
# 49                2.99               2.99                0.00
#
#     total_selling_price  total_margin
# 0                  0.42          0.42
# 1                  0.44          0.44
# 2                  0.45          0.45
# 3                  0.45          0.45
# 4                  0.48          0.48
# 5                  0.50          0.50
# 6                  0.50          0.50
# 7                  0.53          0.53
# 8                  0.53          0.53
# 9                  0.54          0.54
# 10                 0.55          0.55
# 11                 0.56          0.56
# 12                 0.56          0.56
# 13                 0.58          0.58
# 14                 0.71          0.71
# 15                 0.84          0.84
# 16                 0.86          0.86
# 17                 0.87          0.87
# 18                 0.89          0.89
# 19                 0.91          0.91
# 20                 0.93          0.93
# 21                 0.94          0.94
# 22                 0.94          0.94
# 23                 0.94          0.94
# 24                 0.96          0.96
# 25                 0.96          0.96
# 26                 0.99          0.99
# 27                 1.00          1.00
# 28                 1.00          1.00
# 29                 1.00          1.00
# 30                 1.00          1.00
# 31                 1.01          1.01
# 32                 1.01          1.01
# 33                 1.01          1.01
# 34                 1.02          1.02
# 35                 1.02          1.02
# 36                 1.02          1.02
# 37                 1.03          1.03
# 38                 1.03          1.03
# 39                 1.05          1.05
# 40                 1.06          1.06
# 41                 1.07          1.07
# 42                 1.08          1.08
# 43                 1.08          1.08
# 44                 1.08          1.08
# 45                 1.09          1.09
# 46                 1.11          1.11
# 47                 1.11          1.11
# 48                 1.11          1.11
# 49                 1.11          1.11

# %% [markdown]
# # Part 4: High Level Item Analysis

# %%
# Using the Group By and Agg Pandas Functions
# Create a dataframe using "trans_df" called "items_df" that has the following columns:
    # item_name
    # unit_buying_price (Mean of Unit Buying Price)
    # unit_selling_price (Mean of Unit Selling Price)
    # unit_price_margin (Mean of Unit Price Margin)
    # quantity (Sum of Quantity)
    # investment (Sum of Total Buying Price)
    # revenue (Sum of Total Selling Price)
    # profit (Sum of Total Margin)
    
items_df = trans_df.groupby(["item_name"]).agg(unit_buying_price = ("unit_buying_price", "mean"), 
                                              unit_selling_price = ("unit_selling_price", "mean"), 
                                              unit_price_margin = ("unit_price_margin", "mean"), 
                                              quantity = ("quantity", "sum"), 
                                              investment = ("total_buying_price", "sum"), 
                                             revenue = ("total_selling_price", "sum"),
                                              profit = ("total_margin", "sum"))

# Print the top 20 items in items_df by the profit column in ascending order
items_df.sort_values("profit", ascending = True).head(20)
# Out:
#                          unit_buying_price  unit_selling_price  \
# item_name
# Cabbage Wombok                        3.75                1.50
# Pear Nashi                            4.00                2.99
# Red Radish bunch                      2.50                1.80
# Avocado Hass Medium                   3.00                1.99
# Banana Cavendish                      2.00                1.99
# bitter melon                          5.00                4.50
# Turmeric                             45.00               25.00
# grapes Calmeria                       3.50                1.99
# Longans                              10.00                8.50
# Gold Nugget700g                       2.20                2.00
# Brown Onion 1Kg                       1.50                1.20
# choy sum 2 for $ 1.99                 2.00                1.99
# Piel de Sapo Melon                    3.00                2.99
# Lemon 1kg                             2.75                1.99
# Artichoke 2 For 3                     3.60                3.00
# Artichoke Purple                      2.00                2.00
# Rockmelon Half                        1.00                1.00
# Mix Medley Tomatoes                   2.00                2.00
# Delmage Tea Pouch 200g                3.75                3.75
# Lettuce Salad mix loose              12.00               12.00
#
#                          unit_price_margin  quantity  investment   revenue  \
# item_name
# Cabbage Wombok                       -2.25    121.85      456.95    182.78
# Pear Nashi                           -1.01    256.43    1,025.71    766.72
# Red Radish bunch                     -0.70    222.00      555.00    399.60
# Avocado Hass Medium                  -1.01    146.00      438.00    290.54
# Banana Cavendish                     -0.01 13,835.85   27,671.71 27,533.35
# bitter melon                         -0.50    209.63    1,048.16    943.34
# Turmeric                            -20.00      2.20       99.18     55.10
# grapes Calmeria                      -1.51     23.87       83.55     47.50
# Longans                              -1.50     16.57      165.68    140.83
# Gold Nugget700g                      -0.20     69.00      151.80    138.00
# Brown Onion 1Kg                      -0.30     18.00       27.00     21.60
# choy sum 2 for $ 1.99                -0.01    409.00      818.00    813.91
# Piel de Sapo Melon                   -0.01    273.00      819.00    816.27
# Lemon 1kg                            -0.76      2.00        5.50      3.98
# Artichoke 2 For 3                    -0.60      1.00        3.60      3.00
# Artichoke Purple                      0.00    288.00      576.00    576.00
# Rockmelon Half                        0.00      9.00        9.00      9.00
# Mix Medley Tomatoes                   0.00     61.00      122.00    122.00
# Delmage Tea Pouch 200g                0.00      7.00       26.25     26.25
# Lettuce Salad mix loose               0.00    131.95    1,583.40  1,583.40
#
#                          profit
# item_name
# Cabbage Wombok          -274.17
# Pear Nashi              -258.99
# Red Radish bunch        -155.40
# Avocado Hass Medium     -147.46
# Banana Cavendish        -138.36
# bitter melon            -104.82
# Turmeric                 -44.08
# grapes Calmeria          -36.04
# Longans                  -24.85
# Gold Nugget700g          -13.80
# Brown Onion 1Kg           -5.40
# choy sum 2 for $ 1.99     -4.09
# Piel de Sapo Melon        -2.73
# Lemon 1kg                 -1.52
# Artichoke 2 For 3         -0.60
# Artichoke Purple           0.00
# Rockmelon Half             0.00
# Mix Medley Tomatoes        0.00
# Delmage Tea Pouch 200g     0.00
# Lettuce Salad mix loose    0.00

# %% [markdown]
# # Part 5: Filtering

# %%
# DO NOT DELETE THIS LINE
# Reset the index of items_df 
items_df = items_df.reset_index()

# %%
# Make a datframe called "high_revenue_df" that has only items that earned a revenue above or equal to 5,000
high_revenue_df = items_df[items_df["revenue"]>=5000]

# Print high_revenue_df in descending order of revenue
high_revenue_df.sort_values("revenue", ascending = False)
# Out:
#                             unit_buying_price  unit_selling_price  \
# item_name
# Banana Cavendish                         2.00                1.99
# Watermelon seedless                      1.00                1.49
# Field Tomatoes                           1.60                2.99
# Eggplant                                 0.00                6.99
# Cherries                                 0.00               15.99
# Lettuce Iceberg                          0.00                2.50
# Capsicum red                             0.00                4.99
# Cucumber Lebanese                        0.00                4.99
# Apples Pink Lady                         0.00                2.99
# Potato sweet Gold                        0.00                2.99
# Tomatoes Truss                           0.00                5.99
# Crimson Grapes                           0.00                4.99
# Potato brushed                           2.25                2.50
# Grapes black                             0.00                3.99
# Apples Fuji                              0.00                3.99
# Berries Strawberry (large)               3.33                3.80
# Okra                                     8.35                9.99
# Pear Packham                             2.00                2.99
# Orange navel                             0.00                2.99
# Cucumber continental                     0.00                1.50
# Mandarin Imperial                        1.00                2.50
# Broccoli                                 0.00                3.50
#
#                             unit_price_margin  quantity  investment   revenue  \
# item_name
# Banana Cavendish                        -0.01 13,835.85   27,671.71 27,533.35
# Watermelon seedless                      0.49 10,717.21   10,717.21 15,968.64
# Field Tomatoes                           1.39  4,155.75    6,649.20 12,425.70
# Eggplant                                 6.99  1,273.11        0.00  8,899.01
# Cherries                                15.99    539.15        0.00  8,621.02
# Lettuce Iceberg                          2.50  2,962.00        0.00  7,405.00
# Capsicum red                             4.99  1,367.85        0.00  6,825.56
# Cucumber Lebanese                        4.99  1,365.60        0.00  6,814.34
# Apples Pink Lady                         2.99  2,158.53        0.00  6,453.99
# Potato sweet Gold                        2.99  2,100.75        0.00  6,281.25
# Tomatoes Truss                           5.99  1,048.48        0.00  6,280.38
# Crimson Grapes                           4.99  1,231.11        0.00  6,143.24
# Potato brushed                           0.25  2,427.61    5,462.12  6,069.02
# Grapes black                             3.99  1,425.46        0.00  5,687.57
# Apples Fuji                              3.99  1,421.21        0.00  5,670.63
# Berries Strawberry (large)               0.47  1,426.00    4,748.58  5,418.80
# Okra                                     1.64    526.69    4,397.88  5,261.65
# Pear Packham                             0.99  1,751.95    3,503.90  5,238.33
# Orange navel                             2.99  1,750.79        0.00  5,234.85
# Cucumber continental                     1.50  3,437.00        0.00  5,155.50
# Mandarin Imperial                        1.50  2,056.72    2,056.72  5,141.79
# Broccoli                                 3.50  1,431.44        0.00  5,010.05
#
#                              profit
# item_name
# Banana Cavendish            -138.36
# Watermelon seedless        5,251.43
# Field Tomatoes             5,776.50
# Eggplant                   8,899.01
# Cherries                   8,621.02
# Lettuce Iceberg            7,405.00
# Capsicum red               6,825.56
# Cucumber Lebanese          6,814.34
# Apples Pink Lady           6,453.99
# Potato sweet Gold          6,281.25
# Tomatoes Truss             6,280.38
# Crimson Grapes             6,143.24
# Potato brushed               606.90
# Grapes black               5,687.57
# Apples Fuji                5,670.63
# Berries Strawberry (large)   670.22
# Okra                         863.77
# Pear Packham               1,734.43
# Orange navel               5,234.85
# Cucumber continental       5,155.50
# Mandarin Imperial          3,085.07
# Broccoli                   5,010.05
